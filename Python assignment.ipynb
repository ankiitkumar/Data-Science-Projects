# %% [markdown]
# <a href="https://colab.research.google.com/github/ankiitkumar/Data-Science-Projects/blob/main/Python%20assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/RevolveSolutions/backend-engineer.git
# Out:
# Cloning into 'backend-engineer'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 13 (delta 2), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
# !tar -xvf "/content/backend-engineer/data.tar.gz" -C "/content/"
# Out:
# data/
# data/airports.csv
# data/flights.csv
# data/airlines.csv
# data/planes.csv
# data/weather.csv

# %%
import pandas as pd

# %%
airlines = pd.read_csv("/content/data/airlines.csv")

# %%
airlines.head(5)
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airports = pd.read_csv("/content/data/airports.csv")
flights = pd.read_csv("/content/data/flights.csv")
planes = pd.read_csv("/content/data/planes.csv")
weather = pd.read_csv("/content/data/weather.csv")

# %%
flights.head(10)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 5  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
# 6  2013      1    1     555.0       -5.0     913.0       19.0      B6  N516JB
# 7  2013      1    1     557.0       -3.0     709.0      -14.0      EV  N829AS
# 8  2013      1    1     557.0       -3.0     838.0       -8.0      B6  N593JB
# 9  2013      1    1     558.0       -2.0     753.0        8.0      AA  N3ALAA
#
#    flight origin dest  air_time  distance  hour  minute
# ...

# %%
flights.shape
# Out:
# (336776, 16)

# %%
flights.head(10)
# Out:
#    year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier tailnum  \
# 0  2013      1    1     517.0        2.0     830.0       11.0      UA  N14228
# 1  2013      1    1     533.0        4.0     850.0       20.0      UA  N24211
# 2  2013      1    1     542.0        2.0     923.0       33.0      AA  N619AA
# 3  2013      1    1     544.0       -1.0    1004.0      -18.0      B6  N804JB
# 4  2013      1    1     554.0       -6.0     812.0      -25.0      DL  N668DN
# 5  2013      1    1     554.0       -4.0     740.0       12.0      UA  N39463
# 6  2013      1    1     555.0       -5.0     913.0       19.0      B6  N516JB
# 7  2013      1    1     557.0       -3.0     709.0      -14.0      EV  N829AS
# 8  2013      1    1     557.0       -3.0     838.0       -8.0      B6  N593JB
# 9  2013      1    1     558.0       -2.0     753.0        8.0      AA  N3ALAA
#
#    flight origin dest  air_time  distance  hour  minute
# ...

# %%
airports.head(5)
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
planes.head(10)
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
# 5  N105UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 6  N107US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 7  N108UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 8  N109UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 9  N110UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# ...

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     1  39.02  26.06  59.37     270.0    10.35702
# 1    EWR  2013      1    1     2  39.02  26.96  61.63     250.0     8.05546
# 2    EWR  2013      1    1     3  39.02  28.04  64.43     240.0    11.50780
# 3    EWR  2013      1    1     4  39.92  28.04  62.21     250.0    12.65858
# 4    EWR  2013      1    1     5  39.02  28.04  64.43     260.0    12.65858
#
#    wind_gust  precip  pressure  visib             time_hour
# 0        NaN     0.0    1012.0   10.0  2013-01-01T06:00:00Z
# 1        NaN     0.0    1012.3   10.0  2013-01-01T07:00:00Z
# 2        NaN     0.0    1012.5   10.0  2013-01-01T08:00:00Z
# 3        NaN     0.0    1012.2   10.0  2013-01-01T09:00:00Z
# 4        NaN     0.0    1011.9   10.0  2013-01-01T10:00:00Z

# %%
flights['dest'].value_counts()
# Out:
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
#        ...
# MTJ       15
# SBN       10
# ANC        8
# LEX        1
# LGA        1
# Name: dest, Length: 105, dtype: int64

# %%
airports[airports.IATA_CODE=="ORD"]['CITY']
# Out:
# 228    Chicago
# Name: CITY, dtype: object

# %%
airports[airports.IATA_CODE=="ATL"]['CITY']
# Out:
# 20    Atlanta
# Name: CITY, dtype: object

# %%
#### Chicago & Atlanta are the 2 most connected cities ####

# %%
## Question 5 starts here.
def ques5(value):
  city_name = airports[airports.IATA_CODE==value]['CITY']
  return city_name

# %%
ques5("ORD")
# Out:
# 228    Chicago
# Name: CITY, dtype: object

# %%
ques5("ATL")
# Out:
# 20    Atlanta
# Name: CITY, dtype: object

# %%
flights['origin'].unique()
# Out:
# array(['EWR', 'LGA', 'JFK'], dtype=object)

# %%
flights['origin'].value_counts()
# Out:
# EWR    120835
# JFK    111279
# LGA    104662
# Name: origin, dtype: int64

# %%
flights['origin'].value_counts().sum()
# Out:
# 336776

# %%
def ques2(column):
  city_count = flights[column].unique().shape
  return city_count

# %%
ques2("origin")
# Out:
# (3,)

# %%
### Flights database cover 3 cities. ###

# %%
flights['dep_delay'].max()
# Out:
# 1301.0

# %%
flights[flights.dep_delay==flights.dep_delay.max()]['tailnum']
# Out:
# 7072    N384HA
# Name: tailnum, dtype: object

# %%
planes[planes.tailnum=="N384HA"]['manufacturer']
# Out:
# 1062    AIRBUS
# Name: manufacturer, dtype: object

# %%
### 'AIRBUS' incurred the most delays in the analysis period ####
